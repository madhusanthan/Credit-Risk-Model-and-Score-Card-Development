# %%
import pandas as pd
import seaborn as sns
import numpy as np
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, cross_val_score
warnings.filterwarnings("ignore")

# %%
loan_data_clean = pd.read_csv("loan_data_clean.csv", header = 0, index_col = 0)

# %%
loan_data_clean.head(5)
# Out:
#            funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# loan_amnt
# 5000              5000           4975.0    36     10.65       162.87     B
# 2500              2500           2500.0    60     15.27        59.83     C
# 2400              2400           2400.0    36     15.96        84.33     C
# 10000            10000          10000.0    36     13.49       339.31     C
# 3000              3000           3000.0    60     12.69        67.79     B
#
#           sub_grade  emp_length home_ownership  annual_inc  ...  \
# loan_amnt                                                   ...
# 5000             B2        10.0           RENT     24000.0  ...
# 2500             C4         0.0           RENT     30000.0  ...
# 2400             C5        10.0           RENT     12252.0  ...
# 10000            C1        10.0           RENT     49200.0  ...
# 3000             B5         1.0           RENT     80000.0  ...
#
#           collections_12_mths_ex_med policy_code  application_type  \
# loan_amnt
# 5000                             0.0           1        INDIVIDUAL
# 2500                             0.0           1        INDIVIDUAL
# 2400                             0.0           1        INDIVIDUAL
# 10000                            0.0           1        INDIVIDUAL
# 3000                             0.0           1        INDIVIDUAL
#
#            acc_now_delinq  total_rev_hi_lim  good_bad  \
# loan_amnt
# 5000                  0.0      30379.087771         1
# 2500                  0.0      30379.087771         0
# 2400                  0.0      30379.087771         1
# 10000                 0.0      30379.087771         1
# 3000                  0.0      30379.087771         1
#
#            mths_since_earliest_cr_line  mths_since_issue_d  \
# loan_amnt
# 5000                             427.0               104.0
# 2500                             256.0               104.0
# 2400                             225.0               104.0
# 10000                            294.0               104.0
# 3000                             295.0               104.0
#
#            mths_since_last_pymnt_d  mths_since_last_credit_pull_d
# loan_amnt
# 5000                          67.0                           55.0
# 2500                          88.0                           83.0
# 2400                          74.0                           55.0
# 10000                         67.0                           67.0
# 3000                          55.0                           55.0
#
# [5 rows x 39 columns]

# %%
loan_data_clean.columns
# Out:
# Index(['funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment',
#        'grade', 'sub_grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'purpose', 'dti', 'delinq_2yrs',
#        'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv',
#        'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'last_pymnt_amnt', 'collections_12_mths_ex_med',
#        'policy_code', 'application_type', 'acc_now_delinq', 'total_rev_hi_lim',
#        'good_bad', 'mths_since_earliest_cr_line', 'mths_since_issue_d',
#        'mths_since_last_pymnt_d', 'mths_since_last_credit_pull_d'],
#       dtype='object')

# %%
# To see which columns still have the nan values, and impute these nan values. 
loan_data_clean.isnull().sum()
# Out:
# funded_amnt                        0
# funded_amnt_inv                    0
# term                               0
# int_rate                           0
# installment                        0
# grade                              0
# sub_grade                          0
# emp_length                         0
# home_ownership                     0
# annual_inc                         4
# verification_status                0
# purpose                            0
# dti                                0
# delinq_2yrs                       29
# inq_last_6mths                    29
# open_acc                          29
# pub_rec                           29
# revol_bal                          0
# revol_util                         0
# total_acc                         29
# initial_list_status                0
# out_prncp                          0
# out_prncp_inv                      0
# total_pymnt                        0
# total_pymnt_inv                    0
# total_rec_prncp                    0
# total_rec_int                      0
# total_rec_late_fee                 0
# last_pymnt_amnt                    0
# collections_12_mths_ex_med       145
# policy_code                        0
# application_type                   0
# acc_now_delinq                     0
# total_rev_hi_lim                   0
# good_bad                           0
# mths_since_earliest_cr_line       29
# mths_since_issue_d                 0
# mths_since_last_pymnt_d          376
# mths_since_last_credit_pull_d     42
# dtype: int64

# %%
loan_data_clean.fillna(0, inplace=True)

# %%
loan_dummy_df = pd.get_dummies(loan_data_clean)
loan_dummy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 466285 entries, 5000 to 10000
# Data columns (total 100 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   funded_amnt                          466285 non-null  int64
#  1   funded_amnt_inv                      466285 non-null  float64
#  2   term                                 466285 non-null  int64
#  3   int_rate                             466285 non-null  float64
#  4   installment                          466285 non-null  float64
#  5   emp_length                           466285 non-null  float64
#  6   annual_inc                           466285 non-null  float64
#  7   dti                                  466285 non-null  float64
#  8   delinq_2yrs                          466285 non-null  float64
#  9   inq_last_6mths                       466285 non-null  float64
#  10  open_acc                             466285 non-null  float64
#  11  pub_rec                              466285 non-null  float64
#  12  revol_bal                            466285 non-null  int64
#  13  revol_util                           466285 non-null  float64
#  14  total_acc                            466285 non-null  float64
#  15  out_prncp                            466285 non-null  float64
#  16  out_prncp_inv                        466285 non-null  float64
#  17  total_pymnt                          466285 non-null  float64
#  18  total_pymnt_inv                      466285 non-null  float64
#  19  total_rec_prncp                      466285 non-null  float64
#  20  total_rec_int                        466285 non-null  float64
#  21  total_rec_late_fee                   466285 non-null  float64
#  22  last_pymnt_amnt                      466285 non-null  float64
#  23  collections_12_mths_ex_med           466285 non-null  float64
#  24  policy_code                          466285 non-null  int64
#  25  acc_now_delinq                       466285 non-null  float64
#  26  total_rev_hi_lim                     466285 non-null  float64
#  27  good_bad                             466285 non-null  int64
#  28  mths_since_earliest_cr_line          466285 non-null  float64
#  29  mths_since_issue_d                   466285 non-null  float64
#  30  mths_since_last_pymnt_d              466285 non-null  float64
#  31  mths_since_last_credit_pull_d        466285 non-null  float64
#  32  grade_A                              466285 non-null  uint8
#  33  grade_B                              466285 non-null  uint8
#  34  grade_C                              466285 non-null  uint8
#  35  grade_D                              466285 non-null  uint8
#  36  grade_E                              466285 non-null  uint8
#  37  grade_F                              466285 non-null  uint8
#  38  grade_G                              466285 non-null  uint8
#  39  sub_grade_A1                         466285 non-null  uint8
#  40  sub_grade_A2                         466285 non-null  uint8
#  41  sub_grade_A3                         466285 non-null  uint8
#  42  sub_grade_A4                         466285 non-null  uint8
#  43  sub_grade_A5                         466285 non-null  uint8
#  44  sub_grade_B1                         466285 non-null  uint8
#  45  sub_grade_B2                         466285 non-null  uint8
#  46  sub_grade_B3                         466285 non-null  uint8
#  47  sub_grade_B4                         466285 non-null  uint8
#  48  sub_grade_B5                         466285 non-null  uint8
#  49  sub_grade_C1                         466285 non-null  uint8
#  50  sub_grade_C2                         466285 non-null  uint8
#  51  sub_grade_C3                         466285 non-null  uint8
#  52  sub_grade_C4                         466285 non-null  uint8
#  53  sub_grade_C5                         466285 non-null  uint8
#  54  sub_grade_D1                         466285 non-null  uint8
#  55  sub_grade_D2                         466285 non-null  uint8
#  56  sub_grade_D3                         466285 non-null  uint8
#  57  sub_grade_D4                         466285 non-null  uint8
#  58  sub_grade_D5                         466285 non-null  uint8
#  59  sub_grade_E1                         466285 non-null  uint8
#  60  sub_grade_E2                         466285 non-null  uint8
#  61  sub_grade_E3                         466285 non-null  uint8
#  62  sub_grade_E4                         466285 non-null  uint8
#  63  sub_grade_E5                         466285 non-null  uint8
#  64  sub_grade_F1                         466285 non-null  uint8
#  65  sub_grade_F2                         466285 non-null  uint8
#  66  sub_grade_F3                         466285 non-null  uint8
#  67  sub_grade_F4                         466285 non-null  uint8
#  68  sub_grade_F5                         466285 non-null  uint8
#  69  sub_grade_G1                         466285 non-null  uint8
#  70  sub_grade_G2                         466285 non-null  uint8
#  71  sub_grade_G3                         466285 non-null  uint8
#  72  sub_grade_G4                         466285 non-null  uint8
#  73  sub_grade_G5                         466285 non-null  uint8
#  74  home_ownership_ANY                   466285 non-null  uint8
#  75  home_ownership_MORTGAGE              466285 non-null  uint8
#  76  home_ownership_NONE                  466285 non-null  uint8
#  77  home_ownership_OTHER                 466285 non-null  uint8
#  78  home_ownership_OWN                   466285 non-null  uint8
#  79  home_ownership_RENT                  466285 non-null  uint8
#  80  verification_status_Not Verified     466285 non-null  uint8
#  81  verification_status_Source Verified  466285 non-null  uint8
#  82  verification_status_Verified         466285 non-null  uint8
#  83  purpose_car                          466285 non-null  uint8
#  84  purpose_credit_card                  466285 non-null  uint8
#  85  purpose_debt_consolidation           466285 non-null  uint8
#  86  purpose_educational                  466285 non-null  uint8
#  87  purpose_home_improvement             466285 non-null  uint8
#  88  purpose_house                        466285 non-null  uint8
#  89  purpose_major_purchase               466285 non-null  uint8
#  90  purpose_medical                      466285 non-null  uint8
#  91  purpose_moving                       466285 non-null  uint8
#  92  purpose_other                        466285 non-null  uint8
#  93  purpose_renewable_energy             466285 non-null  uint8
#  94  purpose_small_business               466285 non-null  uint8
#  95  purpose_vacation                     466285 non-null  uint8
#  96  purpose_wedding                      466285 non-null  uint8
#  97  initial_list_status_f                466285 non-null  uint8
#  98  initial_list_status_w                466285 non-null  uint8
#  99  application_type_INDIVIDUAL          466285 non-null  uint8
# dtypes: float64(27), int64(5), uint8(68)
# memory usage: 147.6 MB

# %%
# save new dataset for checkpointing
# loan_dummy_df.to_csv("loan_dummy.csv", index=False)
print(loan_dummy_df.shape)

# splitting into test and train after treating variables
X_train, X_test, y_train, y_test = train_test_split(loan_dummy_df, loan_data_clean['good_bad'], 
                                                    test_size=0.3, stratify = loan_data_clean['good_bad'], #to keep class balance during splitting,
                                                    random_state=42)
# Out:
# (466285, 100)

# %%
X_train.drop(columns=['good_bad'], axis=1, inplace=True)
X_test.drop(columns=['good_bad'], axis=1, inplace=True)

# %% [markdown]
# ## Feature Selection

# %%
from scipy.stats import chi2_contingency
from sklearn.feature_selection import f_classif
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV, KFold,RepeatedStratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.feature_selection import SelectKBest, VarianceThreshold, RFE, f_regression, mutual_info_regression
import time

# metrics
from sklearn import metrics
from sklearn.metrics import accuracy_score,f1_score,precision_score, recall_score,auc,roc_curve,confusion_matrix
from statistics import mean

# models
from sklearn import model_selection
from sklearn import ensemble
from sklearn.linear_model import LogisticRegression, Ridge, Lasso, LassoLars, LinearRegression, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBClassifier

# %% [markdown]
# ## Full Model
#
# First, we will attempt to train a number of machine learning algorithms on the full subset of predictors at our disposal. For all of the models, we train ans test the model's performance. This lets us form unbiased predictions since we test on “uncontaminated” data.

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
y_pred = model.score(X_test, y_test)
print(f'Accuracy is: {y_pred*100.0: 0.3f}')
# Out:
# Accuracy is:  98.072

# %%
model = DecisionTreeClassifier(random_state=99)
model.fit(X_train, y_train)
result = model.score(X_test, y_test)
print(f'accuracy is: {result*100.0: 0.3f}')
# Out:
# accuracy is:  99.043

# %%
model = KNeighborsClassifier(n_neighbors = 1)
model.fit(X_train, y_train)
result = model.score(X_test, y_test)
print(f'accuracy is: {result*100.0: 0.3f}')
# Out:
# accuracy is:  95.794

# %%
X = loan_dummy_df
Y = loan_data_clean['good_bad']

# %%
seedValue = 99
MLA_columns = []
MLA_compare = pd.DataFrame(columns = MLA_columns)
row_index = 0
# prepare configuration for cross validation test harness
# prepare models
models = []
models.append(('Logistic Regression', LogisticRegression()))
models.append(('XGBoost', XGBClassifier(eval_metric='mlogloss')))
models.append(('Decision Tree Classifer', DecisionTreeClassifier()))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'

# Create StratifiedKFold object.    
tic = time.perf_counter()
for name, model in models:
    skfold = model_selection.StratifiedKFold(n_splits = 5, shuffle = True, random_state=seedValue)
    cv_results = model_selection.cross_val_score(model, X, Y, cv=skfold, scoring=scoring)
    f1_results = model_selection.cross_val_score(model, X, Y, cv=skfold, scoring='f1')
    recall_results = model_selection.cross_val_score(model, X, Y, cv=skfold, scoring='recall')
    precision_results = model_selection.cross_val_score(model, X, Y, cv=skfold, scoring='precision')
    roc_auc_results = model_selection.cross_val_score(model, X, Y, cv=skfold, scoring='roc_auc')
    MLA_compare.loc[row_index,'MLA used'] = name
    MLA_compare.loc[row_index, 'Test Accuracy'] = round(mean(cv_results), 4)
    MLA_compare.loc[row_index, 'Precision'] = round(mean(precision_results),4)
    MLA_compare.loc[row_index, 'Recall'] = round(mean(recall_results),4)
    MLA_compare.loc[row_index, 'f1'] = mean(f1_results)
    MLA_compare.loc[row_index, 'roc_auc'] = mean(roc_auc_results)
    results.append(cv_results)
    names.append(name)
    # Print the output.
    print('List of possible accuracies for {0} is: {1}'.format(name, cv_results))
    print('List of possible Precision for {0} is: {1}'.format(name, precision_results))
    print('List of possible Recall for {0} is: {1}'.format(name, recall_results))
    print('List of possible F1 score for {0} is: {1}'.format(name, f1_results))
    print('List of possible ROC_AUC for {0} is: {1}'.format(name, roc_auc_results))
    msg = "%s: %f (%f)" % (name, mean(cv_results), cv_results.std())
    print(msg)
    toc = time.perf_counter()
    secs = toc - tic
    print("---Classifier %s use %0.4f seconds ---" %(name, secs))
    row_index+=1
    
MLA_compare.sort_values(by = ['Test Accuracy'], ascending = False, inplace = True)    
MLA_compare
# Out:
# List of possible accuracies for Logistic Regression is: [0.98130971 0.98142767 0.9811167  0.98094513 0.98192093]
# List of possible Precision for Logistic Regression is: [0.97950399 0.97974424 0.97925067 0.97962001 0.98023062]
# List of possible Recall for Logistic Regression is: [0.99993981 0.99981942 0.99998796 0.99939805 0.99986757]
# List of possible F1 score for Logistic Regression is: [0.98961641 0.98968003 0.98951068 0.9894102  0.98995173]
# List of possible ROC_AUC for Logistic Regression is: [0.9565127  0.95907888 0.95680259 0.95955572 0.95914343]
# Logistic Regression: 0.981344 (0.000332)
# ---Classifier Logistic Regression use 247.9367 seconds ---
# List of possible accuracies for XGBoost is: [0.99656862 0.99630055 0.99620404 0.99625765 0.99679381]
# List of possible Precision for XGBoost is: [0.99635282 0.99616118 0.9960774  0.99616095 0.99675886]
# List of possible Recall for XGBoost is: [0.99980738 0.99969903 0.99967495 0.99965087 0.99965087]
# List of possible F1 score for XGBoost is: [0.99807711 0.99792697 0.99787293 0.99790286 0.99820277]
# List of possible ROC_AUC for XGBoost is: [0.99772588 0.9978261  0.99731962 0.99760377 0.997968  ]
# XGBoost: 0.996425 (0.000223)
# ---Classifier XGBoost use 1775.6457 seconds ---
# List of possible accuracies for Decision Tree Classifer is: [0.9913036  0.99020985 0.9896737  0.99100336 0.990746  ]
# List of possible Precision for Decision Tree Classifer is: [0.99546895 0.99460384 0.99452065 0.99449961 0.99522817]
# List of possible Recall for Decision Tree Classifer is: [0.99469084 0.99435375 0.99445    0.99497971 0.99437776]
# List of possible F1 score for Decision Tree Classifer is: [0.9950749  0.9942981  0.99441906 0.99486624 0.99479088]
# List of possible ROC_AUC for Decision Tree Classifer is: [0.9789968  0.97583448 0.97427991 0.97556274 0.97748433]
# Decision Tree Classifer: 0.990587 (0.000581)
# ---Classifier Decision Tree Classifer use 2513.9259 seconds ---
#                   MLA used  Test Accuracy  Precision  Recall        f1  \
# 1                  XGBoost         0.9964     0.9963  0.9997  0.997997
# 2  Decision Tree Classifer         0.9906     0.9949  0.9946  0.994690
# 0      Logistic Regression         0.9813     0.9797  0.9998  0.989634
#
#     roc_auc
# 1  0.997689
# 2  0.976432
# 0  0.958219
